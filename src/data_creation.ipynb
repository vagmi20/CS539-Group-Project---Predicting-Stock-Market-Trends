# %%
import pandas as pd
import numpy as np
import finnhub
# Out:
# /Users/puttu/Documents/GitHub/CS539_groupProject/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
finnhub_client = finnhub.Client(api_key="co0u5e9r01qhaf74u6b0co0u5e9r01qhaf74u6bg")

# %%
print(finnhub_client.symbol_lookup('apple'))
# Out:
# {'count': 22, 'result': [{'description': 'Apple', 'displaySymbol': 'APCX.MU', 'symbol': 'APCX.MU', 'type': ''}, {'description': 'Apple', 'displaySymbol': 'A3KUT4.MU', 'symbol': 'A3KUT4.MU', 'type': ''}, {'description': 'Apple', 'displaySymbol': 'A3KUT3.BE', 'symbol': 'A3KUT3.BE', 'type': ''}, {'description': 'Apple', 'displaySymbol': 'APCT.BE', 'symbol': 'APCT.BE', 'type': ''}, {'description': 'Apple', 'displaySymbol': 'APCU.MU', 'symbol': 'APCU.MU', 'type': ''}, {'description': 'Apple', 'displaySymbol': 'A1HKKY.MU', 'symbol': 'A1HKKY.MU', 'type': ''}, {'description': 'Apple', 'displaySymbol': 'APCX.BE', 'symbol': 'APCX.BE', 'type': ''}, {'description': 'Apple', 'displaySymbol': 'APCU.BE', 'symbol': 'APCU.BE', 'type': ''}, {'description': 'Apple', 'displaySymbol': 'A3LHSQ.BE', 'symbol': 'A3LHSQ.BE', 'type': ''}, {'description': 'Apple', 'displaySymbol': 'A3K78T.BE', 'symbol': 'A3K78T.BE', 'type': ''}, {'description': 'Apple', 'displaySymbol': 'APCT.HM', 'symbol': 'APCT.HM', 'type': ''}, {'description': 'Apple', 'displaySymbol': 'A3KUT4.DU', 'symbol': 'A3KUT4.DU', 'type': ''}, {'description': 'Apple', 'displaySymbol': 'A3LHSP.MU', 'symbol': 'A3LHSP.MU', 'type': ''}, {'description': 'Apple', 'displaySymbol': 'A3LHSR.BE', 'symbol': 'A3LHSR.BE', 'type': ''}, {'description': 'Apple', 'displaySymbol': 'A3LHSR.DU', 'symbol': 'A3LHSR.DU', 'type': ''}, {'description': 'Apple', 'displaySymbol': 'APC5.MU', 'symbol': 'APC5.MU', 'type': ''}, {'description': 'Apple', 'displaySymbol': 'APCL.HA', 'symbol': 'APCL.HA', 'type': ''}, {'description': 'Apple', 'displaySymbol': 'A3KUT5.DU', 'symbol': 'A3KUT5.DU', 'type': ''}, {'description': 'Apple', 'displaySymbol': 'A3KUT5.BE', 'symbol': 'A3KUT5.BE', 'type': ''}, {'description': 'Apple', 'displaySymbol': 'A3KUT6.DU', 'symbol': 'A3KUT6.DU', 'type': ''}, {'description': 'Apple', 'displaySymbol': 'A1HKKY.HA', 'symbol': 'A1HKKY.HA', 'type': ''}, {'description': 'Apple', 'displaySymbol': 'APCU.HA', 'symbol': 'APCU.HA', 'type': ''}]}

# %%
import os
# Out:
# '.'

# %%
# List of desired stock symbols
AI_companies_stocks = pd.read_csv("AI_Companies_Stock_List.csv")
stocksSymbols = list(AI_companies_stocks['Stock Symbol'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # List of desired stock symbols
# ----> 2 AI_companies_stocks = pd.read_csv("..//data//AI_Companies_Stock_List.csv")
#       3 stocksSymbols = list(AI_companies_stocks['Stock Symbol'])
#
# File ~/Documents/GitHub/CS539_groupProject/.venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Documents/GitHub/CS539_groupProject/.venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Documents/GitHub/CS539_groupProject/.venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Documents/GitHub/CS539_groupProject/.venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Documents/GitHub/CS539_groupProject/.venv/lib/python3.9/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '..//data//AI_Companies_Stock_List.csv'

# %%
import yfinance as yf

# Define the time period
start_date = "2024-02-26"
end_date = "2024-03-26"

# %%
frames = []

for i in range(len(stocksSymbols)):
    data = yf.download(stocksSymbols[i], start=start_date, end=end_date).reset_index()
    data['Symbol'] = stocksSymbols[i]

    frames.append(data)

aggregated_stock_df = pd.concat(frames)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
aggregated_stock_df.to_csv("aggregated_stock_data.csv")

# %%
# Calculate average closing prices by date
average_closing_by_date = aggregated_stock_df['Close'].mean(axis=1)

# Add this as a new column to the summary_df
aggregated_stock_df['Avg Closing Price'] = aggregated_stock_df.index.map(average_closing_by_date)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Documents/GitHub/CS539_groupProject/.venv/lib/python3.9/site-packages/pandas/core/generic.py in ?(cls, axis)
#     575             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     576         except KeyError:
# --> 577             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/k4/_hldxhq51zjbjxv_dl82pmmr0000gn/T/ipykernel_21053/3996580195.py in ?()
# ----> 2 # Calculate average closing prices by date
#       3 average_closing_by_date = aggregated_stock_df['Close'].mean(axis=1)
#       4
#       5 # Add this as a new column to the summary_df
#
# ~/Documents/GitHub/CS539_groupProject/.venv/lib/python3.9/site-packages/pandas/core/series.py in ?(self, axis, skipna, numeric_only, **kwargs)
#    6536         skipna: bool = True,
#    6537         numeric_only: bool = False,
#    6538         **kwargs,
#    6539     ):
# -> 6540         return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# ~/Documents/GitHub/CS539_groupProject/.venv/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, axis, skipna, numeric_only, **kwargs)
#   12413         skipna: bool_t = True,
#   12414         numeric_only: bool_t = False,
#   12415         **kwargs,
#   12416     ) -> Series | float:
# > 12417         return self._stat_function(
#   12418             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12419         )
#
# ~/Documents/GitHub/CS539_groupProject/.venv/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12370         nv.validate_func(name, (), kwargs)
#   12371
#   12372         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   12373
# > 12374         return self._reduce(
#   12375             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12376         )
#
# ~/Documents/GitHub/CS539_groupProject/.venv/lib/python3.9/site-packages/pandas/core/series.py in ?(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6426         """
#    6427         delegate = self._values
#    6428
#    6429         if axis is not None:
# -> 6430             self._get_axis_number(axis)
#    6431
#    6432         if isinstance(delegate, ExtensionArray):
#    6433             # dispatch to ExtensionArray interface
#
# ~/Documents/GitHub/CS539_groupProject/.venv/lib/python3.9/site-packages/pandas/core/generic.py in ?(cls, axis)
#     573     def _get_axis_number(cls, axis: Axis) -> AxisInt:
#     574         try:
#     575             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     576         except KeyError:
# --> 577             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# ValueError: No axis named 1 for object type Series

# %%
# Check current data types
print(aggregated_stock_df.dtypes)

# # Define the file path where you want to save the CSV file
# file_path = 'D:/Datasets/stock_summary.csv'
#
# # Export the summary DataFrame to a CSV file
# summary_df.to_csv(file_path, index=True)
#
# print(f"File saved to {file_path}")

# print(summary_df)
# Out:
# Price
# Ticker                object
# Adj Close            float64
# Close                float64
# High                 float64
# Low                  float64
# Open                 float64
# Volume                 int64
